# %% [markdown]
# <a href="https://colab.research.google.com/github/s9611890/computation/blob/master/Week3_Group_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("我是廖思勳")
# Out:
# 我是廖思勳

# %%
print("我4陳政霆")

# %%
print("我是陳明偉")
# Out:
# 我是陳明偉
